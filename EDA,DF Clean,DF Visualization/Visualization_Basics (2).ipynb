# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_id = '18Aie7PXX77qZj1mFHp2YXw-gzBstu19p'
url = f"https://drive.google.com/uc?export=download&id={file_id}"

# %%
df = pd.read_csv(url)
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# # Charts For Numerical Data

# %% [markdown]
# **1- Bar Chart:** How oftern each value occured?

# %%
df['bedrooms'].value_counts()
# Out:
# bedrooms
# 3    300
# 2    136
# 4     95
# 5     10
# 6      2
# 1      2
# Name: count, dtype: int64

# %%
plt.bar(df['bedrooms'].value_counts().index, df['bedrooms'].value_counts())
plt.show()

# %%
sns.countplot(x='bedrooms', hue= 'furnishingstatus',data=df)
plt.show()

# %% [markdown]
# **2- Histogram**: showing the distribution

# %%
plt.hist(df['price'], bins=10)
plt.show()

# %% [markdown]
# **3- scatterplot:** plotting the relationship between 2 variables

# %%
plt.scatter(df['area'], df['price'], marker='o', color='green')
plt.title('Area vs Price')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(df['area'], df['price'], marker='o', color=df['price'])
plt.title('Area vs Price')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **4-Boxplot:** To visualize outliers

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame({
    'EmployeeID': [101, 102, 103, 104, 105, 106, 107],
    'Salary': [15000, 12000, 13000, 200000, 11000, 12500, 300000],
    'Age': [25, 30, 28, 27, 26, 29, 22]

})

# %%
plt.boxplot(df['Salary'],whis=3)
plt.show()

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = max(0, Q1 - 3* IQR)
upper_bound = Q3 + 3* IQR

print(f"Salary lower bound: {lower_bound}, upper bound: {upper_bound}")
# Out:
# Salary lower bound: 0, upper bound: 393250.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Salary'])
plt.axhline(y=lower_bound, color='r', linestyle='--', label=f'Lower Bound (3*IQR): {lower_bound:.2f}')
plt.axhline(y=upper_bound, color='g', linestyle='--', label=f'Upper Bound (3*IQR): {upper_bound:.2f}')
plt.title('Boxplot of Salary with 3*IQR Bounds')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %%
sns.boxplot(x='price', data=df)
plt.show()

# %% [markdown]
# # Charts For Categorical Values

# %% [markdown]
# **1- barchart** : what is the frequency of each value?

# %%
furnishing_counts = df['furnishingstatus'].value_counts()
colors = ['blue', 'green', 'red']

bars = plt.bar(furnishing_counts.index, furnishing_counts.values, color=colors)

plt.xlabel('Furnishing Status')
plt.ylabel('Number of Houses')
plt.title('Number of Houses by Furnishing Status')

plt.legend(bars, furnishing_counts.index, title='Furnishing Status')

plt.show()

# %% [markdown]
# **2-Countplot**: also for frequency

# %%
sns.countplot(x='furnishingstatus', data=df)
plt.show()

# %% [markdown]
# **3- Pie Chart**

# %%
plt.pie(furnishing_counts, labels=furnishing_counts.index,  autopct='%1.1f%%')
plt.title('Furnishing Status Distribution')
# Out:
# Text(0.5, 1.0, 'Furnishing Status Distribution')

# %% [markdown]
# # Visualizing a Categorical and a Quantitative Variable

# %% [markdown]
# Catplot in seaborn allow us to plot a categorical variable with a numerical one with different charts

# %%
sns.catplot(x='furnishingstatus', y='price', data=df, kind='bar')
plt.show()

# %%
sns.catplot(x='airconditioning', y='price', data=df, kind='box')
plt.show()

# %% [markdown]
# # Visualizing Relationship Between Two Numerical Variables

# %%
sns.relplot(x='area', y='price', data=df, kind='scatter', col='mainroad')
plt.show()

# %%
sns.relplot(x='area', y='price', data=df, kind='scatter', col='hotwaterheating')
plt.show()

# %%
df['hotwaterheating'].value_counts()
# Out:
# hotwaterheating
# no     520
# yes     25
# Name: count, dtype: int64

# %%
sns.relplot(x='area', y='price', data=df, kind='scatter', col='furnishingstatus')
plt.show()

# %%
sns.relplot(x='area', y='price', data=df, kind='scatter', col='basement')
plt.show()

# %%
sns.relplot(x='bedrooms', y='area', data=df, kind='line', style='furnishingstatus' )
plt.show()

# %%
sns.relplot(x='area', y='price', data=df, kind='scatter', hue='bedrooms', size='bedrooms')
plt.show()

# %% [markdown]
# # Pairplots

# %%
sns.pairplot(data = df)
plt.show()

# %%
#                                                      For all numerical variables
 
#fig, ax = plt.subplots(4,4, figsize=(16, 12))
#
#i = 0
#j = 0
#for var in df.columns:
#    if var in var_discrete:
#        sns.countplot(x = var, data = df, color = 'skyblue', ax=ax[i,j])
#    else:
#        sns.histplot(df[var], bins = 40, kde = True, color = 'skyblue', edgecolor = 'black', ax=ax[i,j])
#    ax[i,j].set_title(var)
#    ax[i,j].set_xlabel(var)
#    ax[i,j].set_ylabel('Count')
#
#    if j==3:
#        j=0
#        i+=1
#    else:
#        j+=1
#
#plt.tight_layout()
#plt.show()

# %% [markdown]
# # Heatmap

# %%
numerical_data= df.select_dtypes(include='number')
numerical_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  parking
# 0  13300000  7420         4          2        3        2
# 1  12250000  8960         4          4        4        3
# 2  12250000  9960         3          2        2        2
# 3  12215000  7500         4          2        2        3
# 4  11410000  7420         4          1        2        2

# %%
numerical_data.corr()
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
sns.heatmap(numerical_data.corr(), annot=True)
plt.show()

# %%
cats= df.select_dtypes(include='object').columns
cats
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
categorical_data = pd.get_dummies(df[cats], drop_first=True)
categorical_data.head()
# Out:
#    mainroad_yes  guestroom_yes  basement_yes  hotwaterheating_yes  \
# 0          True          False         False                False
# 1          True          False         False                False
# 2          True          False          True                False
# 3          True          False          True                False
# 4          True           True          True                False
#
#    airconditioning_yes  prefarea_yes  furnishingstatus_semi-furnished  \
# 0                 True          True                            False
# 1                 True         False                            False
# 2                False          True                             True
# 3                 True          True                            False
# 4                 True         False                            False
#
#    furnishingstatus_unfurnished
# 0                         False
# 1                         False
# 2                         False
# ...

# %%
categorical_data['price'] = df['price']

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(categorical_data.corr(), annot=True)
plt.show()

# %%
numerical_cols = df.select_dtypes(include='number').columns
numerical_cols
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking'], dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
