# %% [markdown]
# # 🐼 Pandas Homework — Real Estate Insights
#
# **Estimated time:** ~1 hour
#
# **Goal:** apply data cleaning, filtering, derived columns, grouping, sorting, and a chart —
# on the same house price dataset — as one connected mini-analysis.
#
# Work through the tasks in order. Add your code in the empty cell under each task.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("House Price Prediction Dataset.csv")
data.columns = data.columns.str.strip().str.lower()
data.head()
# Out:
#    id  area  bedrooms  bathrooms  floors  yearbuilt  location  condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   garage   price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %% [markdown]
# ## Task 1 — Clean up missing values (10 min)
#
# - Check how many missing values exist in each column.
# - For every numeric column that has missing values, fill it using that column's **median**
#   (briefly, in a markdown cell, say why median rather than mean makes sense for this data).
#   If only one numeric column has missing values, that's fine — just handle whichever ones do.
# - Confirm afterward that those columns have zero missing values.

# %%
# Your code here

# %% [markdown]
# ## Task 2 — Create a derived column (10 min)
#
# Create a new column `price_per_sqft = price / area`.
#
# Then answer: what is the average `price_per_sqft` across the whole dataset?

# %%
# Your code here

# %% [markdown]
# ## Task 3 — Filter for a target segment (10 min)
#
# Filter the dataset to houses that meet **all** of the following:
# - more than 3 bedrooms
# - `prefarea == 'yes'`
# - `airconditioning == 'yes'`
#
# How many houses match? What is their average `price`?

# %%
# Your code here

# %% [markdown]
# ## Task 4 — Group and compare (10 min)
#
# Using the **full** dataset (not just the Task 3 filter), group by `furnishingstatus` and
# compute, in one `groupby(...).agg(...)` call:
# - average `price`
# - average `price_per_sqft`
# - count of houses in each group
#
# Which furnishing category has the highest average `price_per_sqft`?

# %%
# Your code here

# %% [markdown]
# ## Task 5 — Bucket houses by size (10 min)
#
# Using `apply` with a function (or lambda), create a new column `size_category` that labels
# each house based on `area`:
# - `'small'` if area < 4000
# - `'medium'` if 4000 ≤ area < 8000
# - `'large'` if area ≥ 8000
#
# Then use `value_counts()` to see how many houses fall into each bucket.

# %%
# Your code here

# %% [markdown]
# ## Task 6 — Top 10 by value (5 min)
#
# Using `sort_values`, print the top 10 houses by `price_per_sqft`, showing only the columns
# `price`, `area`, `price_per_sqft`, and `furnishingstatus`.

# %%
# Your code here

# %% [markdown]
# ## Task 7 — One chart (5 min)
#
# Make a bar chart of average `price` by `size_category` (from Task 5). Label the axes.

# %%
# Your code here

# %% [markdown]
# ## 🌟 Bonus — Pivot table (optional, ~10 min)
#
# Build a `pivot_table` showing average `price` with `size_category` as rows and
# `airconditioning` as columns. What pattern do you notice?

# %%
# Your code here

# %% [markdown]
# ---
# ### Submission checklist
# - [ ] All 7 tasks run without errors, top to bottom
# - [ ] `price_per_sqft` and `size_category` columns exist in the final `data`
# - [ ] The Task 7 chart has axis labels and a title
# - [ ] One sentence per task (in a markdown cell) stating the actual finding, not just the code
